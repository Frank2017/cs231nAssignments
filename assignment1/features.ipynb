# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# (49000, 32, 32, 3) (49000,) (1000, 32, 32, 3) (1000,) (1000, 32, 32, 3) (1000,)

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

print X_train_feats.shape
print X_test_feats.shape
print X_val_feats.shape
from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [1e5, 1e6, 1e7]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for lr in learning_rates:
    for rs in regularization_strengths:
        svmTemp = LinearSVM()
        svmTemp.train(X_train_feats, y_train, learning_rate=lr,reg=rs,num_iters=1000)
        train_pred = svmTemp.predict(X_train_feats)
        train_accu = np.mean(train_pred == y_train)
        val_pred = svmTemp.predict(X_val_feats)
        val_accu = np.mean(val_pred == y_val)
        results[(lr,rs)] = (train_accu, val_accu)
        if val_accu > best_val:
            best_val = val_accu
            best_svm = svmTemp
pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# (49000, 155)
# (1000, 155)
# (1000, 155)
# lr 1.000000e-09 reg 1.000000e+05 train accuracy: 0.109102 val accuracy: 0.120000
# lr 1.000000e-09 reg 1.000000e+06 train accuracy: 0.082061 val accuracy: 0.082000
# lr 1.000000e-09 reg 1.000000e+07 train accuracy: 0.309612 val accuracy: 0.313000
# lr 1.000000e-08 reg 1.000000e+05 train accuracy: 0.091980 val accuracy: 0.114000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.411735 val accuracy: 0.407000
# lr 1.000000e-08 reg 1.000000e+07 train accuracy: 0.404918 val accuracy: 0.387000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.416980 val accuracy: 0.429000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.411837 val accuracy: 0.425000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.305102 val accuracy: 0.298000
# best validation accuracy achieved during cross-validation: 0.429000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.432

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000, 155)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 50
num_classes = 10

# net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None
best_stats = None
best_val = -1
results = {}
count = 100
for i in np.arange(count):
    lr = 10**np.random.uniform(-3,-1)
    rs = 10 ** np.random.uniform(-3,0)
    hidden_dim = int(10 ** np.random.uniform(1.7, 2.5))
    net = TwoLayerNet(input_dim, hidden_dim, num_classes)
    stats = net.train(X_train_feats, y_train, X_val_feats, y_val, learning_rate=lr, learning_rate_decay=0.95, reg=rs,
                    mu=0.5,num_iters=2000,batch_size=200,verbose=True)
    val_temp = (net.predict(X_val_feats) == y_val).mean()
    print "learning rate",lr
    print "regularization strength:", rs
    print "Hidden layer is",hidden_dim
    print "accuarcy ", val_temp
    results[(lr,rs,hidden_dim)] = val_temp
    if val_temp > best_val:
        best_val = val_temp
        best_net = net
        best_stats = stats

# best net lr 0.093783 rs 0.003960 hidden_size 172  val accuracy: 0.569000
for lr, rs, hd in sorted(results):
    val_accuracy = results[(lr,rs,hd)]
    print 'lr %f rs %f hidden_size %d  val accuracy: %f' % (lr, rs, hd, val_accuracy)

print 'best validation accuracy achieved during cross-validation: %f' % best_val

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.301503
# iteration 200 / 2000: loss 2.298575
# iteration 300 / 2000: loss 2.109147
# iteration 400 / 2000: loss 1.888053
# iteration 500 / 2000: loss 1.735874
# iteration 600 / 2000: loss 1.585203
# iteration 700 / 2000: loss 1.547111
# iteration 800 / 2000: loss 1.545542
# iteration 900 / 2000: loss 1.504258
# iteration 1000 / 2000: loss 1.412684
# iteration 1100 / 2000: loss 1.276934
# iteration 1200 / 2000: loss 1.505041
# iteration 1300 / 2000: loss 1.475051
# iteration 1400 / 2000: loss 1.449179
# iteration 1500 / 2000: loss 1.513350
# iteration 1600 / 2000: loss 1.323435
# iteration 1700 / 2000: loss 1.368588
# iteration 1800 / 2000: loss 1.315343
# iteration 1900 / 2000: loss 1.379220
# learning rate 0.0411080230279
# regularization strength: 0.00628034685528
# Hidden layer is 50
# accuarcy  0.506
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.301564
# iteration 200 / 2000: loss 2.164249
# iteration 300 / 2000: loss 1.810489
# iteration 400 / 2000: loss 1.682413
# iteration 500 / 2000: loss 1.567165
# iteration 600 / 2000: loss 1.440280
# iteration 700 / 2000: loss 1.576068
# iteration 800 / 2000: loss 1.459299
# iteration 900 / 2000: loss 1.562596
# iteration 1000 / 2000: loss 1.424955
# iteration 1100 / 2000: loss 1.480512
# iteration 1200 / 2000: loss 1.523686
# iteration 1300 / 2000: loss 1.457025
# iteration 1400 / 2000: loss 1.408425
# iteration 1500 / 2000: loss 1.376333
# iteration 1600 / 2000: loss 1.387805
# iteration 1700 / 2000: loss 1.357944
# iteration 1800 / 2000: loss 1.348200
# iteration 1900 / 2000: loss 1.331667
# learning rate 0.0566017510271
# regularization strength: 0.00459723613472
# Hidden layer is 50
# accuarcy  0.531
# iteration 0 / 2000: loss 2.302592
# iteration 100 / 2000: loss 2.302607
# iteration 200 / 2000: loss 2.302549
# iteration 300 / 2000: loss 2.302574
# iteration 400 / 2000: loss 2.302661
# iteration 500 / 2000: loss 2.302485
# iteration 600 / 2000: loss 2.302629
# iteration 700 / 2000: loss 2.302513
# iteration 800 / 2000: loss 2.302535
# iteration 900 / 2000: loss 2.302578
# iteration 1000 / 2000: loss 2.302731
# iteration 1100 / 2000: loss 2.302649
# iteration 1200 / 2000: loss 2.302580
# iteration 1300 / 2000: loss 2.302557
# iteration 1400 / 2000: loss 2.302522
# iteration 1500 / 2000: loss 2.302695
# iteration 1600 / 2000: loss 2.302545
# iteration 1700 / 2000: loss 2.302614
# iteration 1800 / 2000: loss 2.302579
# iteration 1900 / 2000: loss 2.302597
# learning rate 0.00139094577712
# regularization strength: 0.0653282031342
# Hidden layer is 124
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302614
# iteration 100 / 2000: loss 2.302209
# iteration 200 / 2000: loss 2.302800
# iteration 300 / 2000: loss 2.302479
# iteration 400 / 2000: loss 2.303337
# iteration 500 / 2000: loss 2.302303
# iteration 600 / 2000: loss 2.302543
# iteration 700 / 2000: loss 2.299575
# iteration 800 / 2000: loss 2.296517
# iteration 900 / 2000: loss 2.288022
# iteration 1000 / 2000: loss 2.228741
# iteration 1100 / 2000: loss 2.216620
# iteration 1200 / 2000: loss 2.231230
# iteration 1300 / 2000: loss 2.158712
# iteration 1400 / 2000: loss 2.176839
# iteration 1500 / 2000: loss 2.188423
# iteration 1600 / 2000: loss 2.127832
# iteration 1700 / 2000: loss 2.159164
# iteration 1800 / 2000: loss 2.182838
# iteration 1900 / 2000: loss 2.170785
# learning rate 0.0188288347855
# regularization strength: 0.157357564634
# Hidden layer is 218
# accuarcy  0.292
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302796
# iteration 200 / 2000: loss 2.302632
# iteration 300 / 2000: loss 2.302492
# iteration 400 / 2000: loss 2.302431
# iteration 500 / 2000: loss 2.302557
# iteration 600 / 2000: loss 2.303042
# iteration 700 / 2000: loss 2.302709
# iteration 800 / 2000: loss 2.302582
# iteration 900 / 2000: loss 2.302624
# iteration 1000 / 2000: loss 2.302421
# iteration 1100 / 2000: loss 2.302282
# iteration 1200 / 2000: loss 2.302449
# iteration 1300 / 2000: loss 2.301615
# iteration 1400 / 2000: loss 2.301750
# iteration 1500 / 2000: loss 2.302080
# iteration 1600 / 2000: loss 2.300259
# iteration 1700 / 2000: loss 2.298894
# iteration 1800 / 2000: loss 2.298130
# iteration 1900 / 2000: loss 2.293381
# learning rate 0.00465921789153
# regularization strength: 0.00140526434142
# Hidden layer is 179
# accuarcy  0.147
# iteration 0 / 2000: loss 2.302621
# iteration 100 / 2000: loss 2.301619
# iteration 200 / 2000: loss 2.303342
# iteration 300 / 2000: loss 2.303087
# iteration 400 / 2000: loss 2.301866
# iteration 500 / 2000: loss 2.302076
# iteration 600 / 2000: loss 2.302038
# iteration 700 / 2000: loss 2.302132
# iteration 800 / 2000: loss 2.304752
# iteration 900 / 2000: loss 2.302164
# iteration 1000 / 2000: loss 2.301866
# iteration 1100 / 2000: loss 2.302851
# iteration 1200 / 2000: loss 2.304423
# iteration 1300 / 2000: loss 2.301569
# iteration 1400 / 2000: loss 2.304111
# iteration 1500 / 2000: loss 2.301741
# iteration 1600 / 2000: loss 2.301140
# iteration 1700 / 2000: loss 2.303260
# iteration 1800 / 2000: loss 2.301557
# iteration 1900 / 2000: loss 2.302866
# learning rate 0.0403420276168
# regularization strength: 0.750139625138
# Hidden layer is 58
# accuarcy  0.098
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.302816
# iteration 200 / 2000: loss 2.301366
# iteration 300 / 2000: loss 2.211795
# iteration 400 / 2000: loss 1.999447
# iteration 500 / 2000: loss 1.912038
# iteration 600 / 2000: loss 1.823739
# iteration 700 / 2000: loss 1.711841
# iteration 800 / 2000: loss 1.714933
# iteration 900 / 2000: loss 1.513871
# iteration 1000 / 2000: loss 1.631680
# iteration 1100 / 2000: loss 1.592339
# iteration 1200 / 2000: loss 1.494459
# iteration 1300 / 2000: loss 1.602632
# iteration 1400 / 2000: loss 1.681565
# iteration 1500 / 2000: loss 1.576546
# iteration 1600 / 2000: loss 1.583470
# iteration 1700 / 2000: loss 1.516773
# iteration 1800 / 2000: loss 1.668564
# iteration 1900 / 2000: loss 1.696019
# learning rate 0.0364908086108
# regularization strength: 0.0195546120498
# Hidden layer is 102
# accuarcy  0.503
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.302552
# iteration 200 / 2000: loss 2.302561
# iteration 300 / 2000: loss 2.302520
# iteration 400 / 2000: loss 2.302674
# iteration 500 / 2000: loss 2.302477
# iteration 600 / 2000: loss 2.302481
# iteration 700 / 2000: loss 2.302609
# iteration 800 / 2000: loss 2.302539
# iteration 900 / 2000: loss 2.302537
# iteration 1000 / 2000: loss 2.302708
# iteration 1100 / 2000: loss 2.302494
# iteration 1200 / 2000: loss 2.302588
# iteration 1300 / 2000: loss 2.302484
# iteration 1400 / 2000: loss 2.302581
# iteration 1500 / 2000: loss 2.302423
# iteration 1600 / 2000: loss 2.302530
# iteration 1700 / 2000: loss 2.302551
# iteration 1800 / 2000: loss 2.302327
# iteration 1900 / 2000: loss 2.302530
# learning rate 0.00159211349593
# regularization strength: 0.038025173525
# Hidden layer is 68
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.302547
# iteration 200 / 2000: loss 2.302819
# iteration 300 / 2000: loss 2.302866
# iteration 400 / 2000: loss 2.302338
# iteration 500 / 2000: loss 2.303737
# iteration 600 / 2000: loss 2.302459
# iteration 700 / 2000: loss 2.302952
# iteration 800 / 2000: loss 2.303039
# iteration 900 / 2000: loss 2.302621
# iteration 1000 / 2000: loss 2.302667
# iteration 1100 / 2000: loss 2.301379
# iteration 1200 / 2000: loss 2.301264
# iteration 1300 / 2000: loss 2.298940
# iteration 1400 / 2000: loss 2.291110
# iteration 1500 / 2000: loss 2.282179
# iteration 1600 / 2000: loss 2.270552
# iteration 1700 / 2000: loss 2.253098
# iteration 1800 / 2000: loss 2.199350
# iteration 1900 / 2000: loss 2.156687
# learning rate 0.00805262203486
# regularization strength: 0.0426293179352
# Hidden layer is 54
# accuarcy  0.231
# iteration 0 / 2000: loss 2.302588
# iteration 100 / 2000: loss 2.302612
# iteration 200 / 2000: loss 2.302534
# iteration 300 / 2000: loss 2.302640
# iteration 400 / 2000: loss 2.302489
# iteration 500 / 2000: loss 2.302455
# iteration 600 / 2000: loss 2.302275
# iteration 700 / 2000: loss 2.302805
# iteration 800 / 2000: loss 2.302271
# iteration 900 / 2000: loss 2.303008
# iteration 1000 / 2000: loss 2.303184
# iteration 1100 / 2000: loss 2.302460
# iteration 1200 / 2000: loss 2.301899
# iteration 1300 / 2000: loss 2.302731
# iteration 1400 / 2000: loss 2.302528
# iteration 1500 / 2000: loss 2.302189
# iteration 1600 / 2000: loss 2.302325
# iteration 1700 / 2000: loss 2.301530
# iteration 1800 / 2000: loss 2.300734
# iteration 1900 / 2000: loss 2.300180
# learning rate 0.00473119151695
# regularization strength: 0.0368926462313
# Hidden layer is 95
# accuarcy  0.195
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302599
# iteration 200 / 2000: loss 2.302594
# iteration 300 / 2000: loss 2.302579
# iteration 400 / 2000: loss 2.302590
# iteration 500 / 2000: loss 2.302717
# iteration 600 / 2000: loss 2.302575
# iteration 700 / 2000: loss 2.302646
# iteration 800 / 2000: loss 2.302580
# iteration 900 / 2000: loss 2.302331
# iteration 1000 / 2000: loss 2.302820
# iteration 1100 / 2000: loss 2.302799
# iteration 1200 / 2000: loss 2.302500
# iteration 1300 / 2000: loss 2.302363
# iteration 1400 / 2000: loss 2.302410
# iteration 1500 / 2000: loss 2.302397
# iteration 1600 / 2000: loss 2.302673
# iteration 1700 / 2000: loss 2.302654
# iteration 1800 / 2000: loss 2.302638
# iteration 1900 / 2000: loss 2.302722
# learning rate 0.00122167181548
# regularization strength: 0.0028571974626
# Hidden layer is 216
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302592
# iteration 100 / 2000: loss 2.302497
# iteration 200 / 2000: loss 2.302625
# iteration 300 / 2000: loss 2.302438
# iteration 400 / 2000: loss 2.302845
# iteration 500 / 2000: loss 2.302458
# iteration 600 / 2000: loss 2.302357
# iteration 700 / 2000: loss 2.302786
# iteration 800 / 2000: loss 2.302692
# iteration 900 / 2000: loss 2.303081
# iteration 1000 / 2000: loss 2.303261
# iteration 1100 / 2000: loss 2.302292
# iteration 1200 / 2000: loss 2.301820
# iteration 1300 / 2000: loss 2.301702
# iteration 1400 / 2000: loss 2.302308
# iteration 1500 / 2000: loss 2.301885
# iteration 1600 / 2000: loss 2.301938
# iteration 1700 / 2000: loss 2.300944
# iteration 1800 / 2000: loss 2.300229
# iteration 1900 / 2000: loss 2.298309
# learning rate 0.00527876517915
# regularization strength: 0.0544222357427
# Hidden layer is 144
# accuarcy  0.163
# iteration 0 / 2000: loss 2.302591
# iteration 100 / 2000: loss 2.302508
# iteration 200 / 2000: loss 2.302505
# iteration 300 / 2000: loss 2.302519
# iteration 400 / 2000: loss 2.302738
# iteration 500 / 2000: loss 2.302620
# iteration 600 / 2000: loss 2.302606
# iteration 700 / 2000: loss 2.302430
# iteration 800 / 2000: loss 2.302801
# iteration 900 / 2000: loss 2.302989
# iteration 1000 / 2000: loss 2.302496
# iteration 1100 / 2000: loss 2.302727
# iteration 1200 / 2000: loss 2.302562
# iteration 1300 / 2000: loss 2.302928
# iteration 1400 / 2000: loss 2.302540
# iteration 1500 / 2000: loss 2.302569
# iteration 1600 / 2000: loss 2.302632
# iteration 1700 / 2000: loss 2.302578
# iteration 1800 / 2000: loss 2.302522
# iteration 1900 / 2000: loss 2.302510
# learning rate 0.00153898729223
# regularization strength: 0.0302190451887
# Hidden layer is 225
# accuarcy  0.098
# iteration 0 / 2000: loss 2.302592
# iteration 100 / 2000: loss 2.302583
# iteration 200 / 2000: loss 2.302587
# iteration 300 / 2000: loss 2.302824
# iteration 400 / 2000: loss 2.302673
# iteration 500 / 2000: loss 2.302660
# iteration 600 / 2000: loss 2.302892
# iteration 700 / 2000: loss 2.302745
# iteration 800 / 2000: loss 2.300865
# iteration 900 / 2000: loss 2.299161
# iteration 1000 / 2000: loss 2.295581
# iteration 1100 / 2000: loss 2.286353
# iteration 1200 / 2000: loss 2.258403
# iteration 1300 / 2000: loss 2.237727
# iteration 1400 / 2000: loss 2.187309
# iteration 1500 / 2000: loss 2.136251
# iteration 1600 / 2000: loss 2.132159
# iteration 1700 / 2000: loss 2.060658
# iteration 1800 / 2000: loss 2.093292
# iteration 1900 / 2000: loss 2.073333
# learning rate 0.0091720996681
# regularization strength: 0.0433450867942
# Hidden layer is 189
# accuarcy  0.288
# iteration 0 / 2000: loss 2.302592
# iteration 100 / 2000: loss 2.303154
# iteration 200 / 2000: loss 2.299846
# iteration 300 / 2000: loss 2.272583
# iteration 400 / 2000: loss 2.192981
# iteration 500 / 2000: loss 2.131879
# iteration 600 / 2000: loss 2.199899
# iteration 700 / 2000: loss 2.136170
# iteration 800 / 2000: loss 2.100611
# iteration 900 / 2000: loss 2.118610
# iteration 1000 / 2000: loss 2.151103
# iteration 1100 / 2000: loss 2.060634
# iteration 1200 / 2000: loss 2.133097
# iteration 1300 / 2000: loss 2.068082
# iteration 1400 / 2000: loss 2.116398
# iteration 1500 / 2000: loss 2.066818
# iteration 1600 / 2000: loss 2.117314
# iteration 1700 / 2000: loss 2.110846
# iteration 1800 / 2000: loss 2.042664
# iteration 1900 / 2000: loss 2.044218
# learning rate 0.0591723734291
# regularization strength: 0.155226688623
# Hidden layer is 56
# accuarcy  0.363
# iteration 0 / 2000: loss 2.302595
# iteration 100 / 2000: loss 2.302606
# iteration 200 / 2000: loss 2.302484
# iteration 300 / 2000: loss 2.302546
# iteration 400 / 2000: loss 2.302658
# iteration 500 / 2000: loss 2.302637
# iteration 600 / 2000: loss 2.302524
# iteration 700 / 2000: loss 2.302609
# iteration 800 / 2000: loss 2.302601
# iteration 900 / 2000: loss 2.302562
# iteration 1000 / 2000: loss 2.302560
# iteration 1100 / 2000: loss 2.302693
# iteration 1200 / 2000: loss 2.302647
# iteration 1300 / 2000: loss 2.302445
# iteration 1400 / 2000: loss 2.302417
# iteration 1500 / 2000: loss 2.302685
# iteration 1600 / 2000: loss 2.302705
# iteration 1700 / 2000: loss 2.302505
# iteration 1800 / 2000: loss 2.302567
# iteration 1900 / 2000: loss 2.302707
# learning rate 0.00106939311649
# regularization strength: 0.0899759823548
# Hidden layer is 128
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302625
# iteration 100 / 2000: loss 2.301820
# iteration 200 / 2000: loss 2.300675
# iteration 300 / 2000: loss 2.304459
# iteration 400 / 2000: loss 2.302714
# iteration 500 / 2000: loss 2.299240
# iteration 600 / 2000: loss 2.270966
# iteration 700 / 2000: loss 2.260197
# iteration 800 / 2000: loss 2.250506
# iteration 900 / 2000: loss 2.226176
# iteration 1000 / 2000: loss 2.214222
# iteration 1100 / 2000: loss 2.205485
# iteration 1200 / 2000: loss 2.228597
# iteration 1300 / 2000: loss 2.189919
# iteration 1400 / 2000: loss 2.200319
# iteration 1500 / 2000: loss 2.204948
# iteration 1600 / 2000: loss 2.218663
# iteration 1700 / 2000: loss 2.187167
# iteration 1800 / 2000: loss 2.184085
# iteration 1900 / 2000: loss 2.173896
# learning rate 0.0348995401948
# regularization strength: 0.214744068618
# Hidden layer is 224
# accuarcy  0.268
# iteration 0 / 2000: loss 2.302673
# iteration 100 / 2000: loss 2.302438
# iteration 200 / 2000: loss 2.302602
# iteration 300 / 2000: loss 2.301558
# iteration 400 / 2000: loss 2.302824
# iteration 500 / 2000: loss 2.302697
# iteration 600 / 2000: loss 2.302891
# iteration 700 / 2000: loss 2.302513
# iteration 800 / 2000: loss 2.303562
# iteration 900 / 2000: loss 2.303429
# iteration 1000 / 2000: loss 2.303259
# iteration 1100 / 2000: loss 2.301992
# iteration 1200 / 2000: loss 2.302812
# iteration 1300 / 2000: loss 2.303441
# iteration 1400 / 2000: loss 2.302514
# iteration 1500 / 2000: loss 2.302598
# iteration 1600 / 2000: loss 2.303038
# iteration 1700 / 2000: loss 2.302598
# iteration 1800 / 2000: loss 2.303984
# iteration 1900 / 2000: loss 2.303466
# learning rate 0.021671409477
# regularization strength: 0.95244982515
# Hidden layer is 112
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302723
# iteration 200 / 2000: loss 2.302855
# iteration 300 / 2000: loss 2.301402
# iteration 400 / 2000: loss 2.297413
# iteration 500 / 2000: loss 2.241250
# iteration 600 / 2000: loss 2.118423
# iteration 700 / 2000: loss 1.941462
# iteration 800 / 2000: loss 1.868676
# iteration 900 / 2000: loss 1.759739
# iteration 1000 / 2000: loss 1.718463
# iteration 1100 / 2000: loss 1.660731
# iteration 1200 / 2000: loss 1.541138
# iteration 1300 / 2000: loss 1.528423
# iteration 1400 / 2000: loss 1.517047
# iteration 1500 / 2000: loss 1.500172
# iteration 1600 / 2000: loss 1.477138
# iteration 1700 / 2000: loss 1.573125
# iteration 1800 / 2000: loss 1.382270
# iteration 1900 / 2000: loss 1.354112
# learning rate 0.0188674476656
# regularization strength: 0.00176980485089
# Hidden layer is 246
# accuarcy  0.481
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302562
# iteration 200 / 2000: loss 2.141188
# iteration 300 / 2000: loss 1.889540
# iteration 400 / 2000: loss 1.678023
# iteration 500 / 2000: loss 1.583079
# iteration 600 / 2000: loss 1.645812
# iteration 700 / 2000: loss 1.489727
# iteration 800 / 2000: loss 1.553305
# iteration 900 / 2000: loss 1.542404
# iteration 1000 / 2000: loss 1.579109
# iteration 1100 / 2000: loss 1.571035
# iteration 1200 / 2000: loss 1.552366
# iteration 1300 / 2000: loss 1.447405
# iteration 1400 / 2000: loss 1.468439
# iteration 1500 / 2000: loss 1.381599
# iteration 1600 / 2000: loss 1.477225
# iteration 1700 / 2000: loss 1.460235
# iteration 1800 / 2000: loss 1.444897
# iteration 1900 / 2000: loss 1.372796
# learning rate 0.0613787032525
# regularization strength: 0.0116306651382
# Hidden layer is 111
# accuarcy  0.522
# iteration 0 / 2000: loss 2.302589
# iteration 100 / 2000: loss 2.303057
# iteration 200 / 2000: loss 2.302908
# iteration 300 / 2000: loss 2.301781
# iteration 400 / 2000: loss 2.292280
# iteration 500 / 2000: loss 2.212991
# iteration 600 / 2000: loss 2.092758
# iteration 700 / 2000: loss 1.925486
# iteration 800 / 2000: loss 1.926378
# iteration 900 / 2000: loss 1.830156
# iteration 1000 / 2000: loss 1.887024
# iteration 1100 / 2000: loss 1.795777
# iteration 1200 / 2000: loss 1.729765
# iteration 1300 / 2000: loss 1.749353
# iteration 1400 / 2000: loss 1.678589
# iteration 1500 / 2000: loss 1.780094
# iteration 1600 / 2000: loss 1.655326
# iteration 1700 / 2000: loss 1.736278
# iteration 1800 / 2000: loss 1.649726
# iteration 1900 / 2000: loss 1.682645
# learning rate 0.0223198387307
# regularization strength: 0.0295868789025
# Hidden layer is 148
# accuarcy  0.46
# iteration 0 / 2000: loss 2.302627
# iteration 100 / 2000: loss 2.302594
# iteration 200 / 2000: loss 2.302619
# iteration 300 / 2000: loss 2.302602
# iteration 400 / 2000: loss 2.302648
# iteration 500 / 2000: loss 2.302633
# iteration 600 / 2000: loss 2.302654
# iteration 700 / 2000: loss 2.302737
# iteration 800 / 2000: loss 2.302716
# iteration 900 / 2000: loss 2.302633
# iteration 1000 / 2000: loss 2.302679
# iteration 1100 / 2000: loss 2.302602
# iteration 1200 / 2000: loss 2.302705
# iteration 1300 / 2000: loss 2.302487
# iteration 1400 / 2000: loss 2.302659
# iteration 1500 / 2000: loss 2.302521
# iteration 1600 / 2000: loss 2.302692
# iteration 1700 / 2000: loss 2.302568
# iteration 1800 / 2000: loss 2.302634
# iteration 1900 / 2000: loss 2.302833
# learning rate 0.00115486814362
# regularization strength: 0.163792646025
# Hidden layer is 305
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.298430
# iteration 200 / 2000: loss 1.844703
# iteration 300 / 2000: loss 1.697287
# iteration 400 / 2000: loss 1.634342
# iteration 500 / 2000: loss 1.488598
# iteration 600 / 2000: loss 1.422316
# iteration 700 / 2000: loss 1.466600
# iteration 800 / 2000: loss 1.366485
# iteration 900 / 2000: loss 1.335753
# iteration 1000 / 2000: loss 1.387241
# iteration 1100 / 2000: loss 1.288731
# iteration 1200 / 2000: loss 1.386541
# iteration 1300 / 2000: loss 1.345257
# iteration 1400 / 2000: loss 1.379703
# iteration 1500 / 2000: loss 1.272203
# iteration 1600 / 2000: loss 1.362731
# iteration 1700 / 2000: loss 1.395934
# iteration 1800 / 2000: loss 1.509599
# iteration 1900 / 2000: loss 1.284435
# learning rate 0.0731130982009
# regularization strength: 0.00462932484465
# Hidden layer is 212
# accuarcy  0.547
# iteration 0 / 2000: loss 2.302619
# iteration 100 / 2000: loss 2.302627
# iteration 200 / 2000: loss 2.302686
# iteration 300 / 2000: loss 2.302554
# iteration 400 / 2000: loss 2.302625
# iteration 500 / 2000: loss 2.302564
# iteration 600 / 2000: loss 2.302667
# iteration 700 / 2000: loss 2.302670
# iteration 800 / 2000: loss 2.302604
# iteration 900 / 2000: loss 2.302741
# iteration 1000 / 2000: loss 2.302501
# iteration 1100 / 2000: loss 2.302418
# iteration 1200 / 2000: loss 2.302420
# iteration 1300 / 2000: loss 2.302712
# iteration 1400 / 2000: loss 2.302766
# iteration 1500 / 2000: loss 2.302445
# iteration 1600 / 2000: loss 2.302672
# iteration 1700 / 2000: loss 2.302836
# iteration 1800 / 2000: loss 2.302638
# iteration 1900 / 2000: loss 2.302414
# learning rate 0.00145701947639
# regularization strength: 0.250001197127
# Hidden layer is 165
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302610
# iteration 100 / 2000: loss 2.302651
# iteration 200 / 2000: loss 2.302619
# iteration 300 / 2000: loss 2.302242
# iteration 400 / 2000: loss 2.302593
# iteration 500 / 2000: loss 2.302281
# iteration 600 / 2000: loss 2.302699
# iteration 700 / 2000: loss 2.302729
# iteration 800 / 2000: loss 2.302334
# iteration 900 / 2000: loss 2.302959
# iteration 1000 / 2000: loss 2.302829
# iteration 1100 / 2000: loss 2.303067
# iteration 1200 / 2000: loss 2.302470
# iteration 1300 / 2000: loss 2.302539
# iteration 1400 / 2000: loss 2.302638
# iteration 1500 / 2000: loss 2.302268
# iteration 1600 / 2000: loss 2.303520
# iteration 1700 / 2000: loss 2.302315
# iteration 1800 / 2000: loss 2.302594
# iteration 1900 / 2000: loss 2.302738
# learning rate 0.00319116267671
# regularization strength: 0.201104824277
# Hidden layer is 151
# accuarcy  0.102
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302546
# iteration 200 / 2000: loss 2.302465
# iteration 300 / 2000: loss 2.301767
# iteration 400 / 2000: loss 2.302136
# iteration 500 / 2000: loss 2.299905
# iteration 600 / 2000: loss 2.295752
# iteration 700 / 2000: loss 2.262726
# iteration 800 / 2000: loss 2.198785
# iteration 900 / 2000: loss 2.039638
# iteration 1000 / 2000: loss 1.965647
# iteration 1100 / 2000: loss 1.921252
# iteration 1200 / 2000: loss 1.883252
# iteration 1300 / 2000: loss 1.873370
# iteration 1400 / 2000: loss 1.802495
# iteration 1500 / 2000: loss 1.797634
# iteration 1600 / 2000: loss 1.696137
# iteration 1700 / 2000: loss 1.669465
# iteration 1800 / 2000: loss 1.658055
# iteration 1900 / 2000: loss 1.523393
# learning rate 0.0129771594618
# regularization strength: 0.00587830827901
# Hidden layer is 303
# accuarcy  0.424
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.299234
# iteration 200 / 2000: loss 1.860596
# iteration 300 / 2000: loss 1.678823
# iteration 400 / 2000: loss 1.446433
# iteration 500 / 2000: loss 1.473169
# iteration 600 / 2000: loss 1.478123
# iteration 700 / 2000: loss 1.470477
# iteration 800 / 2000: loss 1.577470
# iteration 900 / 2000: loss 1.571345
# iteration 1000 / 2000: loss 1.439180
# iteration 1100 / 2000: loss 1.348256
# iteration 1200 / 2000: loss 1.390371
# iteration 1300 / 2000: loss 1.410640
# iteration 1400 / 2000: loss 1.435708
# iteration 1500 / 2000: loss 1.454092
# iteration 1600 / 2000: loss 1.357764
# iteration 1700 / 2000: loss 1.373763
# iteration 1800 / 2000: loss 1.400195
# iteration 1900 / 2000: loss 1.321187
# learning rate 0.0798520795157
# regularization strength: 0.00867729880316
# Hidden layer is 151
# accuarcy  0.532
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.302611
# iteration 200 / 2000: loss 2.302566
# iteration 300 / 2000: loss 2.302064
# iteration 400 / 2000: loss 2.298096
# iteration 500 / 2000: loss 2.252715
# iteration 600 / 2000: loss 2.160788
# iteration 700 / 2000: loss 2.091888
# iteration 800 / 2000: loss 1.968964
# iteration 900 / 2000: loss 1.934218
# iteration 1000 / 2000: loss 1.871667
# iteration 1100 / 2000: loss 1.765911
# iteration 1200 / 2000: loss 1.784866
# iteration 1300 / 2000: loss 1.648960
# iteration 1400 / 2000: loss 1.622192
# iteration 1500 / 2000: loss 1.669725
# iteration 1600 / 2000: loss 1.632674
# iteration 1700 / 2000: loss 1.632111
# iteration 1800 / 2000: loss 1.588810
# iteration 1900 / 2000: loss 1.684436
# learning rate 0.0199209774661
# regularization strength: 0.0212116619032
# Hidden layer is 138
# accuarcy  0.459
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.302710
# iteration 200 / 2000: loss 2.302524
# iteration 300 / 2000: loss 2.302353
# iteration 400 / 2000: loss 2.302651
# iteration 500 / 2000: loss 2.302471
# iteration 600 / 2000: loss 2.302397
# iteration 700 / 2000: loss 2.302809
# iteration 800 / 2000: loss 2.302167
# iteration 900 / 2000: loss 2.302604
# iteration 1000 / 2000: loss 2.302526
# iteration 1100 / 2000: loss 2.302683
# iteration 1200 / 2000: loss 2.302449
# iteration 1300 / 2000: loss 2.302999
# iteration 1400 / 2000: loss 2.302456
# iteration 1500 / 2000: loss 2.302716
# iteration 1600 / 2000: loss 2.302294
# iteration 1700 / 2000: loss 2.302717
# iteration 1800 / 2000: loss 2.302587
# iteration 1900 / 2000: loss 2.302631
# learning rate 0.00337301139634
# regularization strength: 0.0554494289552
# Hidden layer is 52
# accuarcy  0.087
# iteration 0 / 2000: loss 2.302646
# iteration 100 / 2000: loss 2.302509
# iteration 200 / 2000: loss 2.302395
# iteration 300 / 2000: loss 2.302712
# iteration 400 / 2000: loss 2.302577
# iteration 500 / 2000: loss 2.302492
# iteration 600 / 2000: loss 2.302705
# iteration 700 / 2000: loss 2.303005
# iteration 800 / 2000: loss 2.302500
# iteration 900 / 2000: loss 2.302682
# iteration 1000 / 2000: loss 2.302604
# iteration 1100 / 2000: loss 2.302989
# iteration 1200 / 2000: loss 2.302455
# iteration 1300 / 2000: loss 2.302841
# iteration 1400 / 2000: loss 2.302554
# iteration 1500 / 2000: loss 2.302480
# iteration 1600 / 2000: loss 2.302809
# iteration 1700 / 2000: loss 2.302544
# iteration 1800 / 2000: loss 2.302199
# iteration 1900 / 2000: loss 2.302871
# learning rate 0.0032903506947
# regularization strength: 0.737755396187
# Hidden layer is 100
# accuarcy  0.107
# iteration 0 / 2000: loss 2.302666
# iteration 100 / 2000: loss 2.302554
# iteration 200 / 2000: loss 2.302604
# iteration 300 / 2000: loss 2.302628
# iteration 400 / 2000: loss 2.302665
# iteration 500 / 2000: loss 2.302093
# iteration 600 / 2000: loss 2.302997
# iteration 700 / 2000: loss 2.302683
# iteration 800 / 2000: loss 2.302780
# iteration 900 / 2000: loss 2.302757
# iteration 1000 / 2000: loss 2.302841
# iteration 1100 / 2000: loss 2.302605
# iteration 1200 / 2000: loss 2.302632
# iteration 1300 / 2000: loss 2.302535
# iteration 1400 / 2000: loss 2.302669
# iteration 1500 / 2000: loss 2.303111
# iteration 1600 / 2000: loss 2.303186
# iteration 1700 / 2000: loss 2.302264
# iteration 1800 / 2000: loss 2.302338
# iteration 1900 / 2000: loss 2.302440
# learning rate 0.00669535803305
# regularization strength: 0.721469152505
# Hidden layer is 136
# accuarcy  0.098
# iteration 0 / 2000: loss 2.302629
# iteration 100 / 2000: loss 2.305687
# iteration 200 / 2000: loss 2.303761
# iteration 300 / 2000: loss 2.305133
# iteration 400 / 2000: loss 2.302309
# iteration 500 / 2000: loss 2.299551
# iteration 600 / 2000: loss 2.301708
# iteration 700 / 2000: loss 2.300265
# iteration 800 / 2000: loss 2.300775
# iteration 900 / 2000: loss 2.303125
# iteration 1000 / 2000: loss 2.302413
# iteration 1100 / 2000: loss 2.302673
# iteration 1200 / 2000: loss 2.304061
# iteration 1300 / 2000: loss 2.302394
# iteration 1400 / 2000: loss 2.302106
# iteration 1500 / 2000: loss 2.304119
# iteration 1600 / 2000: loss 2.302771
# iteration 1700 / 2000: loss 2.302272
# iteration 1800 / 2000: loss 2.302350
# iteration 1900 / 2000: loss 2.303934
# learning rate 0.081969700853
# regularization strength: 0.90994998122
# Hidden layer is 58
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302600
# iteration 100 / 2000: loss 2.302636
# iteration 200 / 2000: loss 2.302702
# iteration 300 / 2000: loss 2.302568
# iteration 400 / 2000: loss 2.302407
# iteration 500 / 2000: loss 2.302471
# iteration 600 / 2000: loss 2.302820
# iteration 700 / 2000: loss 2.302452
# iteration 800 / 2000: loss 2.302568
# iteration 900 / 2000: loss 2.302559
# iteration 1000 / 2000: loss 2.302333
# iteration 1100 / 2000: loss 2.302520
# iteration 1200 / 2000: loss 2.302512
# iteration 1300 / 2000: loss 2.302516
# iteration 1400 / 2000: loss 2.302665
# iteration 1500 / 2000: loss 2.302537
# iteration 1600 / 2000: loss 2.302511
# iteration 1700 / 2000: loss 2.302780
# iteration 1800 / 2000: loss 2.302645
# iteration 1900 / 2000: loss 2.302328
# learning rate 0.0022477956675
# regularization strength: 0.151281061446
# Hidden layer is 123
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302604
# iteration 100 / 2000: loss 2.302692
# iteration 200 / 2000: loss 2.302709
# iteration 300 / 2000: loss 2.302822
# iteration 400 / 2000: loss 2.301975
# iteration 500 / 2000: loss 2.302969
# iteration 600 / 2000: loss 2.302449
# iteration 700 / 2000: loss 2.303152
# iteration 800 / 2000: loss 2.302250
# iteration 900 / 2000: loss 2.302170
# iteration 1000 / 2000: loss 2.302959
# iteration 1100 / 2000: loss 2.303494
# iteration 1200 / 2000: loss 2.303023
# iteration 1300 / 2000: loss 2.302743
# iteration 1400 / 2000: loss 2.302864
# iteration 1500 / 2000: loss 2.302879
# iteration 1600 / 2000: loss 2.302756
# iteration 1700 / 2000: loss 2.302911
# iteration 1800 / 2000: loss 2.302807
# iteration 1900 / 2000: loss 2.302521
# learning rate 0.00983114141494
# regularization strength: 0.401045881805
# Hidden layer is 57
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302694
# iteration 200 / 2000: loss 2.302529
# iteration 300 / 2000: loss 2.302673
# iteration 400 / 2000: loss 2.302655
# iteration 500 / 2000: loss 2.302785
# iteration 600 / 2000: loss 2.302616
# iteration 700 / 2000: loss 2.302610
# iteration 800 / 2000: loss 2.302581
# iteration 900 / 2000: loss 2.302526
# iteration 1000 / 2000: loss 2.302596
# iteration 1100 / 2000: loss 2.302592
# iteration 1200 / 2000: loss 2.302447
# iteration 1300 / 2000: loss 2.302676
# iteration 1400 / 2000: loss 2.302582
# iteration 1500 / 2000: loss 2.302521
# iteration 1600 / 2000: loss 2.302733
# iteration 1700 / 2000: loss 2.302531
# iteration 1800 / 2000: loss 2.302622
# iteration 1900 / 2000: loss 2.302456
# learning rate 0.00177513635138
# regularization strength: 0.00224453803817
# Hidden layer is 313
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302670
# iteration 200 / 2000: loss 2.302705
# iteration 300 / 2000: loss 2.303163
# iteration 400 / 2000: loss 2.299246
# iteration 500 / 2000: loss 2.292292
# iteration 600 / 2000: loss 2.239018
# iteration 700 / 2000: loss 2.152463
# iteration 800 / 2000: loss 1.992730
# iteration 900 / 2000: loss 1.864774
# iteration 1000 / 2000: loss 1.878917
# iteration 1100 / 2000: loss 1.818598
# iteration 1200 / 2000: loss 1.822464
# iteration 1300 / 2000: loss 1.814673
# iteration 1400 / 2000: loss 1.684002
# iteration 1500 / 2000: loss 1.577708
# iteration 1600 / 2000: loss 1.565038
# iteration 1700 / 2000: loss 1.557195
# iteration 1800 / 2000: loss 1.567314
# iteration 1900 / 2000: loss 1.459756
# learning rate 0.0161014906935
# regularization strength: 0.00674168287206
# Hidden layer is 241
# accuarcy  0.451
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302595
# iteration 200 / 2000: loss 2.303171
# iteration 300 / 2000: loss 2.302509
# iteration 400 / 2000: loss 2.302289
# iteration 500 / 2000: loss 2.302344
# iteration 600 / 2000: loss 2.296761
# iteration 700 / 2000: loss 2.277787
# iteration 800 / 2000: loss 2.183618
# iteration 900 / 2000: loss 2.081254
# iteration 1000 / 2000: loss 2.076079
# iteration 1100 / 2000: loss 1.981203
# iteration 1200 / 2000: loss 1.840499
# iteration 1300 / 2000: loss 1.795331
# iteration 1400 / 2000: loss 1.774578
# iteration 1500 / 2000: loss 1.731673
# iteration 1600 / 2000: loss 1.754754
# iteration 1700 / 2000: loss 1.641699
# iteration 1800 / 2000: loss 1.625059
# iteration 1900 / 2000: loss 1.639672
# learning rate 0.0136406623465
# regularization strength: 0.00158564197701
# Hidden layer is 75
# accuarcy  0.408
# iteration 0 / 2000: loss 2.302634
# iteration 100 / 2000: loss 2.302405
# iteration 200 / 2000: loss 2.302535
# iteration 300 / 2000: loss 2.302473
# iteration 400 / 2000: loss 2.302730
# iteration 500 / 2000: loss 2.302596
# iteration 600 / 2000: loss 2.302473
# iteration 700 / 2000: loss 2.302581
# iteration 800 / 2000: loss 2.302332
# iteration 900 / 2000: loss 2.302428
# iteration 1000 / 2000: loss 2.302891
# iteration 1100 / 2000: loss 2.302860
# iteration 1200 / 2000: loss 2.302781
# iteration 1300 / 2000: loss 2.302500
# iteration 1400 / 2000: loss 2.302701
# iteration 1500 / 2000: loss 2.302817
# iteration 1600 / 2000: loss 2.302539
# iteration 1700 / 2000: loss 2.302567
# iteration 1800 / 2000: loss 2.302869
# iteration 1900 / 2000: loss 2.302671
# learning rate 0.00659232811012
# regularization strength: 0.364042695755
# Hidden layer is 163
# accuarcy  0.105
# iteration 0 / 2000: loss 2.302614
# iteration 100 / 2000: loss 2.302619
# iteration 200 / 2000: loss 2.302661
# iteration 300 / 2000: loss 2.302681
# iteration 400 / 2000: loss 2.302565
# iteration 500 / 2000: loss 2.302708
# iteration 600 / 2000: loss 2.302579
# iteration 700 / 2000: loss 2.302497
# iteration 800 / 2000: loss 2.302544
# iteration 900 / 2000: loss 2.302514
# iteration 1000 / 2000: loss 2.302579
# iteration 1100 / 2000: loss 2.302809
# iteration 1200 / 2000: loss 2.302563
# iteration 1300 / 2000: loss 2.302446
# iteration 1400 / 2000: loss 2.302702
# iteration 1500 / 2000: loss 2.302871
# iteration 1600 / 2000: loss 2.302707
# iteration 1700 / 2000: loss 2.302498
# iteration 1800 / 2000: loss 2.302755
# iteration 1900 / 2000: loss 2.302650
# learning rate 0.00191502557164
# regularization strength: 0.204904984312
# Hidden layer is 173
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302582
# iteration 200 / 2000: loss 2.302534
# iteration 300 / 2000: loss 2.302543
# iteration 400 / 2000: loss 2.302652
# iteration 500 / 2000: loss 2.302577
# iteration 600 / 2000: loss 2.302575
# iteration 700 / 2000: loss 2.302634
# iteration 800 / 2000: loss 2.302521
# iteration 900 / 2000: loss 2.302516
# iteration 1000 / 2000: loss 2.302623
# iteration 1100 / 2000: loss 2.302747
# iteration 1200 / 2000: loss 2.302464
# iteration 1300 / 2000: loss 2.302429
# iteration 1400 / 2000: loss 2.302878
# iteration 1500 / 2000: loss 2.303112
# iteration 1600 / 2000: loss 2.302669
# iteration 1700 / 2000: loss 2.302365
# iteration 1800 / 2000: loss 2.302413
# iteration 1900 / 2000: loss 2.302449
# learning rate 0.00153833668208
# regularization strength: 0.0102520259223
# Hidden layer is 136
# accuarcy  0.087
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.303682
# iteration 200 / 2000: loss 2.064249
# iteration 300 / 2000: loss 1.700822
# iteration 400 / 2000: loss 1.617429
# iteration 500 / 2000: loss 1.464723
# iteration 600 / 2000: loss 1.431921
# iteration 700 / 2000: loss 1.598445
# iteration 800 / 2000: loss 1.447060
# iteration 900 / 2000: loss 1.272199
# iteration 1000 / 2000: loss 1.475670
# iteration 1100 / 2000: loss 1.498146
# iteration 1200 / 2000: loss 1.417693
# iteration 1300 / 2000: loss 1.511033
# iteration 1400 / 2000: loss 1.246218
# iteration 1500 / 2000: loss 1.275018
# iteration 1600 / 2000: loss 1.231288
# iteration 1700 / 2000: loss 1.304038
# iteration 1800 / 2000: loss 1.343988
# iteration 1900 / 2000: loss 1.376679
# learning rate 0.0698955452734
# regularization strength: 0.00488294944012
# Hidden layer is 55
# accuarcy  0.535
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.302482
# iteration 200 / 2000: loss 2.302603
# iteration 300 / 2000: loss 2.302742
# iteration 400 / 2000: loss 2.302630
# iteration 500 / 2000: loss 2.302124
# iteration 600 / 2000: loss 2.302317
# iteration 700 / 2000: loss 2.302711
# iteration 800 / 2000: loss 2.302193
# iteration 900 / 2000: loss 2.302587
# iteration 1000 / 2000: loss 2.301847
# iteration 1100 / 2000: loss 2.302084
# iteration 1200 / 2000: loss 2.301331
# iteration 1300 / 2000: loss 2.300769
# iteration 1400 / 2000: loss 2.297559
# iteration 1500 / 2000: loss 2.294043
# iteration 1600 / 2000: loss 2.292944
# iteration 1700 / 2000: loss 2.277667
# iteration 1800 / 2000: loss 2.264078
# iteration 1900 / 2000: loss 2.240854
# learning rate 0.00596870860637
# regularization strength: 0.0132155528556
# Hidden layer is 171
# accuarcy  0.208
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302521
# iteration 200 / 2000: loss 2.302607
# iteration 300 / 2000: loss 2.302561
# iteration 400 / 2000: loss 2.302843
# iteration 500 / 2000: loss 2.302436
# iteration 600 / 2000: loss 2.302512
# iteration 700 / 2000: loss 2.302602
# iteration 800 / 2000: loss 2.302505
# iteration 900 / 2000: loss 2.302626
# iteration 1000 / 2000: loss 2.302381
# iteration 1100 / 2000: loss 2.302598
# iteration 1200 / 2000: loss 2.302647
# iteration 1300 / 2000: loss 2.302360
# iteration 1400 / 2000: loss 2.301713
# iteration 1500 / 2000: loss 2.302031
# iteration 1600 / 2000: loss 2.302753
# iteration 1700 / 2000: loss 2.302449
# iteration 1800 / 2000: loss 2.302318
# iteration 1900 / 2000: loss 2.302140
# learning rate 0.00391876109311
# regularization strength: 0.00367253726644
# Hidden layer is 60
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302606
# iteration 100 / 2000: loss 2.302563
# iteration 200 / 2000: loss 2.302811
# iteration 300 / 2000: loss 2.302437
# iteration 400 / 2000: loss 2.302617
# iteration 500 / 2000: loss 2.302564
# iteration 600 / 2000: loss 2.302219
# iteration 700 / 2000: loss 2.303017
# iteration 800 / 2000: loss 2.303407
# iteration 900 / 2000: loss 2.302954
# iteration 1000 / 2000: loss 2.303357
# iteration 1100 / 2000: loss 2.302728
# iteration 1200 / 2000: loss 2.301854
# iteration 1300 / 2000: loss 2.302551
# iteration 1400 / 2000: loss 2.302705
# iteration 1500 / 2000: loss 2.302559
# iteration 1600 / 2000: loss 2.302555
# iteration 1700 / 2000: loss 2.301908
# iteration 1800 / 2000: loss 2.302626
# iteration 1900 / 2000: loss 2.303103
# learning rate 0.00822166907833
# regularization strength: 0.221302230957
# Hidden layer is 118
# accuarcy  0.09
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.301529
# iteration 200 / 2000: loss 2.049265
# iteration 300 / 2000: loss 1.872219
# iteration 400 / 2000: loss 1.671017
# iteration 500 / 2000: loss 1.748700
# iteration 600 / 2000: loss 1.703840
# iteration 700 / 2000: loss 1.673349
# iteration 800 / 2000: loss 1.593819
# iteration 900 / 2000: loss 1.547632
# iteration 1000 / 2000: loss 1.706075
# iteration 1100 / 2000: loss 1.710003
# iteration 1200 / 2000: loss 1.634742
# iteration 1300 / 2000: loss 1.632704
# iteration 1400 / 2000: loss 1.623041
# iteration 1500 / 2000: loss 1.684874
# iteration 1600 / 2000: loss 1.759009
# iteration 1700 / 2000: loss 1.781051
# iteration 1800 / 2000: loss 1.655311
# iteration 1900 / 2000: loss 1.606210
# learning rate 0.0779666507308
# regularization strength: 0.0324523098802
# Hidden layer is 64
# accuarcy  0.504
# iteration 0 / 2000: loss 2.302611
# iteration 100 / 2000: loss 2.302304
# iteration 200 / 2000: loss 2.302711
# iteration 300 / 2000: loss 2.302777
# iteration 400 / 2000: loss 2.302565
# iteration 500 / 2000: loss 2.302510
# iteration 600 / 2000: loss 2.302575
# iteration 700 / 2000: loss 2.302264
# iteration 800 / 2000: loss 2.303079
# iteration 900 / 2000: loss 2.303062
# iteration 1000 / 2000: loss 2.302011
# iteration 1100 / 2000: loss 2.302881
# iteration 1200 / 2000: loss 2.302315
# iteration 1300 / 2000: loss 2.302355
# iteration 1400 / 2000: loss 2.301850
# iteration 1500 / 2000: loss 2.303604
# iteration 1600 / 2000: loss 2.301909
# iteration 1700 / 2000: loss 2.301874
# iteration 1800 / 2000: loss 2.302539
# iteration 1900 / 2000: loss 2.302537
# learning rate 0.00540238419871
# regularization strength: 0.249161474497
# Hidden layer is 127
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302616
# iteration 100 / 2000: loss 2.302400
# iteration 200 / 2000: loss 2.302859
# iteration 300 / 2000: loss 2.302475
# iteration 400 / 2000: loss 2.303004
# iteration 500 / 2000: loss 2.302385
# iteration 600 / 2000: loss 2.302816
# iteration 700 / 2000: loss 2.302603
# iteration 800 / 2000: loss 2.302139
# iteration 900 / 2000: loss 2.302163
# iteration 1000 / 2000: loss 2.302009
# iteration 1100 / 2000: loss 2.302500
# iteration 1200 / 2000: loss 2.302862
# iteration 1300 / 2000: loss 2.303085
# iteration 1400 / 2000: loss 2.302365
# iteration 1500 / 2000: loss 2.302054
# iteration 1600 / 2000: loss 2.302518
# iteration 1700 / 2000: loss 2.302107
# iteration 1800 / 2000: loss 2.301714
# iteration 1900 / 2000: loss 2.301720
# learning rate 0.00770185917525
# regularization strength: 0.177679527371
# Hidden layer is 211
# accuarcy  0.129
# iteration 0 / 2000: loss 2.302592
# iteration 100 / 2000: loss 2.302635
# iteration 200 / 2000: loss 2.302859
# iteration 300 / 2000: loss 2.302509
# iteration 400 / 2000: loss 2.302586
# iteration 500 / 2000: loss 2.302391
# iteration 600 / 2000: loss 2.302690
# iteration 700 / 2000: loss 2.303087
# iteration 800 / 2000: loss 2.302893
# iteration 900 / 2000: loss 2.302023
# iteration 1000 / 2000: loss 2.302577
# iteration 1100 / 2000: loss 2.302594
# iteration 1200 / 2000: loss 2.302514
# iteration 1300 / 2000: loss 2.303055
# iteration 1400 / 2000: loss 2.302145
# iteration 1500 / 2000: loss 2.302366
# iteration 1600 / 2000: loss 2.302236
# iteration 1700 / 2000: loss 2.299654
# iteration 1800 / 2000: loss 2.299256
# iteration 1900 / 2000: loss 2.295103
# learning rate 0.00619804874357
# regularization strength: 0.079613854921
# Hidden layer is 104
# accuarcy  0.144
# iteration 0 / 2000: loss 2.302607
# iteration 100 / 2000: loss 2.300981
# iteration 200 / 2000: loss 2.300760
# iteration 300 / 2000: loss 2.249862
# iteration 400 / 2000: loss 2.150976
# iteration 500 / 2000: loss 2.130131
# iteration 600 / 2000: loss 2.120197
# iteration 700 / 2000: loss 2.094024
# iteration 800 / 2000: loss 2.089803
# iteration 900 / 2000: loss 2.047186
# iteration 1000 / 2000: loss 2.068216
# iteration 1100 / 2000: loss 2.013652
# iteration 1200 / 2000: loss 2.055744
# iteration 1300 / 2000: loss 2.067752
# iteration 1400 / 2000: loss 2.048880
# iteration 1500 / 2000: loss 2.007490
# iteration 1600 / 2000: loss 2.039160
# iteration 1700 / 2000: loss 2.030483
# iteration 1800 / 2000: loss 2.027432
# iteration 1900 / 2000: loss 2.002773
# learning rate 0.0481113414832
# regularization strength: 0.12523714788
# Hidden layer is 209
# accuarcy  0.392
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302599
# iteration 200 / 2000: loss 2.302644
# iteration 300 / 2000: loss 2.302633
# iteration 400 / 2000: loss 2.302629
# iteration 500 / 2000: loss 2.302523
# iteration 600 / 2000: loss 2.302732
# iteration 700 / 2000: loss 2.302617
# iteration 800 / 2000: loss 2.302366
# iteration 900 / 2000: loss 2.302515
# iteration 1000 / 2000: loss 2.302640
# iteration 1100 / 2000: loss 2.302645
# iteration 1200 / 2000: loss 2.302736
# iteration 1300 / 2000: loss 2.302467
# iteration 1400 / 2000: loss 2.302379
# iteration 1500 / 2000: loss 2.302317
# iteration 1600 / 2000: loss 2.302952
# iteration 1700 / 2000: loss 2.302518
# iteration 1800 / 2000: loss 2.302435
# iteration 1900 / 2000: loss 2.302655
# learning rate 0.00168804943321
# regularization strength: 0.00118616133904
# Hidden layer is 129
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.304201
# iteration 200 / 2000: loss 2.193006
# iteration 300 / 2000: loss 1.836756
# iteration 400 / 2000: loss 1.618732
# iteration 500 / 2000: loss 1.539675
# iteration 600 / 2000: loss 1.403557
# iteration 700 / 2000: loss 1.415503
# iteration 800 / 2000: loss 1.387809
# iteration 900 / 2000: loss 1.348474
# iteration 1000 / 2000: loss 1.363517
# iteration 1100 / 2000: loss 1.380962
# iteration 1200 / 2000: loss 1.364782
# iteration 1300 / 2000: loss 1.361600
# iteration 1400 / 2000: loss 1.274521
# iteration 1500 / 2000: loss 1.334724
# iteration 1600 / 2000: loss 1.409870
# iteration 1700 / 2000: loss 1.318481
# iteration 1800 / 2000: loss 1.274748
# iteration 1900 / 2000: loss 1.318311
# learning rate 0.0515539805855
# regularization strength: 0.0020535974931
# Hidden layer is 191
# accuarcy  0.53
# iteration 0 / 2000: loss 2.302590
# iteration 100 / 2000: loss 2.300997
# iteration 200 / 2000: loss 2.302051
# iteration 300 / 2000: loss 2.301584
# iteration 400 / 2000: loss 2.301971
# iteration 500 / 2000: loss 2.292082
# iteration 600 / 2000: loss 2.219554
# iteration 700 / 2000: loss 2.120931
# iteration 800 / 2000: loss 2.065249
# iteration 900 / 2000: loss 1.943886
# iteration 1000 / 2000: loss 1.878636
# iteration 1100 / 2000: loss 1.860367
# iteration 1200 / 2000: loss 1.824440
# iteration 1300 / 2000: loss 1.864022
# iteration 1400 / 2000: loss 1.862201
# iteration 1500 / 2000: loss 1.827212
# iteration 1600 / 2000: loss 1.893519
# iteration 1700 / 2000: loss 1.742988
# iteration 1800 / 2000: loss 1.826098
# iteration 1900 / 2000: loss 1.784780
# learning rate 0.0184156055379
# regularization strength: 0.0352875077128
# Hidden layer is 159
# accuarcy  0.437
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.303456
# iteration 200 / 2000: loss 2.300297
# iteration 300 / 2000: loss 2.115820
# iteration 400 / 2000: loss 1.867393
# iteration 500 / 2000: loss 1.674699
# iteration 600 / 2000: loss 1.593123
# iteration 700 / 2000: loss 1.642292
# iteration 800 / 2000: loss 1.517680
# iteration 900 / 2000: loss 1.528943
# iteration 1000 / 2000: loss 1.340582
# iteration 1100 / 2000: loss 1.420817
# iteration 1200 / 2000: loss 1.416467
# iteration 1300 / 2000: loss 1.350984
# iteration 1400 / 2000: loss 1.343610
# iteration 1500 / 2000: loss 1.405698
# iteration 1600 / 2000: loss 1.467084
# iteration 1700 / 2000: loss 1.391792
# iteration 1800 / 2000: loss 1.489173
# iteration 1900 / 2000: loss 1.279134
# learning rate 0.0370055498308
# regularization strength: 0.00632771617176
# Hidden layer is 155
# accuarcy  0.509
# iteration 0 / 2000: loss 2.302596
# iteration 100 / 2000: loss 2.302414
# iteration 200 / 2000: loss 2.302929
# iteration 300 / 2000: loss 2.302468
# iteration 400 / 2000: loss 2.302876
# iteration 500 / 2000: loss 2.302531
# iteration 600 / 2000: loss 2.302439
# iteration 700 / 2000: loss 2.302468
# iteration 800 / 2000: loss 2.302476
# iteration 900 / 2000: loss 2.302580
# iteration 1000 / 2000: loss 2.302662
# iteration 1100 / 2000: loss 2.302505
# iteration 1200 / 2000: loss 2.302816
# iteration 1300 / 2000: loss 2.302444
# iteration 1400 / 2000: loss 2.302246
# iteration 1500 / 2000: loss 2.302059
# iteration 1600 / 2000: loss 2.301206
# iteration 1700 / 2000: loss 2.300545
# iteration 1800 / 2000: loss 2.301710
# iteration 1900 / 2000: loss 2.298366
# learning rate 0.00483761016289
# regularization strength: 0.0484725818301
# Hidden layer is 275
# accuarcy  0.157
# iteration 0 / 2000: loss 2.302654
# iteration 100 / 2000: loss 2.302724
# iteration 200 / 2000: loss 2.302784
# iteration 300 / 2000: loss 2.302593
# iteration 400 / 2000: loss 2.302701
# iteration 500 / 2000: loss 2.302700
# iteration 600 / 2000: loss 2.302911
# iteration 700 / 2000: loss 2.302427
# iteration 800 / 2000: loss 2.302366
# iteration 900 / 2000: loss 2.303141
# iteration 1000 / 2000: loss 2.302134
# iteration 1100 / 2000: loss 2.302765
# iteration 1200 / 2000: loss 2.302780
# iteration 1300 / 2000: loss 2.302577
# iteration 1400 / 2000: loss 2.302687
# iteration 1500 / 2000: loss 2.302467
# iteration 1600 / 2000: loss 2.302548
# iteration 1700 / 2000: loss 2.302645
# iteration 1800 / 2000: loss 2.302903
# iteration 1900 / 2000: loss 2.302519
# learning rate 0.00642211965085
# regularization strength: 0.397970289355
# Hidden layer is 207
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302492
# iteration 200 / 2000: loss 2.302979
# iteration 300 / 2000: loss 2.302444
# iteration 400 / 2000: loss 2.301777
# iteration 500 / 2000: loss 2.301289
# iteration 600 / 2000: loss 2.297712
# iteration 700 / 2000: loss 2.281573
# iteration 800 / 2000: loss 2.203894
# iteration 900 / 2000: loss 2.104563
# iteration 1000 / 2000: loss 2.018058
# iteration 1100 / 2000: loss 1.947241
# iteration 1200 / 2000: loss 1.933566
# iteration 1300 / 2000: loss 1.780216
# iteration 1400 / 2000: loss 1.781483
# iteration 1500 / 2000: loss 1.819820
# iteration 1600 / 2000: loss 1.695369
# iteration 1700 / 2000: loss 1.758452
# iteration 1800 / 2000: loss 1.704988
# iteration 1900 / 2000: loss 1.615117
# learning rate 0.0145445172847
# regularization strength: 0.0156605021565
# Hidden layer is 96
# accuarcy  0.402
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302229
# iteration 200 / 2000: loss 2.301240
# iteration 300 / 2000: loss 2.188699
# iteration 400 / 2000: loss 1.942698
# iteration 500 / 2000: loss 1.807102
# iteration 600 / 2000: loss 1.643929
# iteration 700 / 2000: loss 1.642977
# iteration 800 / 2000: loss 1.568987
# iteration 900 / 2000: loss 1.417115
# iteration 1000 / 2000: loss 1.448429
# iteration 1100 / 2000: loss 1.529432
# iteration 1200 / 2000: loss 1.415264
# iteration 1300 / 2000: loss 1.436617
# iteration 1400 / 2000: loss 1.395959
# iteration 1500 / 2000: loss 1.371761
# iteration 1600 / 2000: loss 1.404444
# iteration 1700 / 2000: loss 1.442335
# iteration 1800 / 2000: loss 1.333401
# iteration 1900 / 2000: loss 1.386355
# learning rate 0.0350392449798
# regularization strength: 0.00168929995147
# Hidden layer is 110
# accuarcy  0.52
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302137
# iteration 200 / 2000: loss 2.125439
# iteration 300 / 2000: loss 1.857585
# iteration 400 / 2000: loss 1.735513
# iteration 500 / 2000: loss 1.564622
# iteration 600 / 2000: loss 1.497942
# iteration 700 / 2000: loss 1.422488
# iteration 800 / 2000: loss 1.438265
# iteration 900 / 2000: loss 1.529025
# iteration 1000 / 2000: loss 1.661990
# ...
# iteration 1300 / 2000: loss 1.569421
# iteration 1400 / 2000: loss 1.461635
# iteration 1500 / 2000: loss 1.506121
# iteration 1600 / 2000: loss 1.391171
# iteration 1700 / 2000: loss 1.341745
# iteration 1800 / 2000: loss 1.372979
# iteration 1900 / 2000: loss 1.321914
# learning rate 0.0297245713027
# regularization strength: 0.00494316346545
# Hidden layer is 60
# accuarcy  0.515
# iteration 0 / 2000: loss 2.302588
# iteration 100 / 2000: loss 2.294630
# iteration 200 / 2000: loss 1.845619
# iteration 300 / 2000: loss 1.713198
# iteration 400 / 2000: loss 1.462077
# iteration 500 / 2000: loss 1.460026
# iteration 600 / 2000: loss 1.467919
# iteration 700 / 2000: loss 1.451768
# iteration 800 / 2000: loss 1.527822
# iteration 900 / 2000: loss 1.472447
# iteration 1000 / 2000: loss 1.502976
# iteration 1100 / 2000: loss 1.433403
# iteration 1200 / 2000: loss 1.587781
# iteration 1300 / 2000: loss 1.414726
# iteration 1400 / 2000: loss 1.533883
# iteration 1500 / 2000: loss 1.458818
# iteration 1600 / 2000: loss 1.415580
# iteration 1700 / 2000: loss 1.568741
# iteration 1800 / 2000: loss 1.477814
# iteration 1900 / 2000: loss 1.650128
# learning rate 0.0804696783327
# regularization strength: 0.0134716308467
# Hidden layer is 298
# accuarcy  0.525
# iteration 0 / 2000: loss 2.302612
# iteration 100 / 2000: loss 2.302899
# iteration 200 / 2000: loss 2.302614
# iteration 300 / 2000: loss 2.302397
# iteration 400 / 2000: loss 2.302592
# iteration 500 / 2000: loss 2.302491
# iteration 600 / 2000: loss 2.302273
# iteration 700 / 2000: loss 2.302355
# iteration 800 / 2000: loss 2.302401
# iteration 900 / 2000: loss 2.302604
# iteration 1000 / 2000: loss 2.302300
# iteration 1100 / 2000: loss 2.302746
# iteration 1200 / 2000: loss 2.302615
# iteration 1300 / 2000: loss 2.302797
# iteration 1400 / 2000: loss 2.303238
# iteration 1500 / 2000: loss 2.302574
# iteration 1600 / 2000: loss 2.302227
# iteration 1700 / 2000: loss 2.302655
# iteration 1800 / 2000: loss 2.302681
# iteration 1900 / 2000: loss 2.302953
# learning rate 0.00547735571632
# regularization strength: 0.243509890837
# Hidden layer is 137
# accuarcy  0.084
# iteration 0 / 2000: loss 2.302645
# iteration 100 / 2000: loss 2.302499
# iteration 200 / 2000: loss 2.302606
# iteration 300 / 2000: loss 2.302652
# iteration 400 / 2000: loss 2.302453
# iteration 500 / 2000: loss 2.302625
# iteration 600 / 2000: loss 2.302450
# iteration 700 / 2000: loss 2.302268
# iteration 800 / 2000: loss 2.302079
# iteration 900 / 2000: loss 2.303221
# iteration 1000 / 2000: loss 2.303723
# iteration 1100 / 2000: loss 2.301239
# iteration 1200 / 2000: loss 2.303193
# iteration 1300 / 2000: loss 2.301769
# iteration 1400 / 2000: loss 2.303342
# iteration 1500 / 2000: loss 2.302241
# iteration 1600 / 2000: loss 2.302654
# iteration 1700 / 2000: loss 2.302659
# iteration 1800 / 2000: loss 2.302415
# iteration 1900 / 2000: loss 2.301844
# learning rate 0.00608863055996
# regularization strength: 0.503798111189
# Hidden layer is 144
# accuarcy  0.078
# iteration 0 / 2000: loss 2.302587
# iteration 100 / 2000: loss 2.302747
# iteration 200 / 2000: loss 2.302820
# iteration 300 / 2000: loss 2.302686
# iteration 400 / 2000: loss 2.302253
# iteration 500 / 2000: loss 2.302764
# iteration 600 / 2000: loss 2.302688
# iteration 700 / 2000: loss 2.302312
# iteration 800 / 2000: loss 2.302015
# iteration 900 / 2000: loss 2.302741
# iteration 1000 / 2000: loss 2.302499
# iteration 1100 / 2000: loss 2.301426
# iteration 1200 / 2000: loss 2.300406
# iteration 1300 / 2000: loss 2.299892
# iteration 1400 / 2000: loss 2.296727
# iteration 1500 / 2000: loss 2.291760
# iteration 1600 / 2000: loss 2.287747
# iteration 1700 / 2000: loss 2.271124
# iteration 1800 / 2000: loss 2.245930
# iteration 1900 / 2000: loss 2.244770
# learning rate 0.00574509552309
# regularization strength: 0.00678081416966
# Hidden layer is 296
# accuarcy  0.231
# iteration 0 / 2000: loss 2.302586
# iteration 100 / 2000: loss 2.302542
# iteration 200 / 2000: loss 2.302516
# iteration 300 / 2000: loss 2.302750
# iteration 400 / 2000: loss 2.302685
# iteration 500 / 2000: loss 2.302413
# iteration 600 / 2000: loss 2.302342
# iteration 700 / 2000: loss 2.302665
# iteration 800 / 2000: loss 2.302289
# iteration 900 / 2000: loss 2.302419
# iteration 1000 / 2000: loss 2.302297
# iteration 1100 / 2000: loss 2.302495
# iteration 1200 / 2000: loss 2.302473
# iteration 1300 / 2000: loss 2.302190
# iteration 1400 / 2000: loss 2.302544
# iteration 1500 / 2000: loss 2.302751
# iteration 1600 / 2000: loss 2.302933
# iteration 1700 / 2000: loss 2.302418
# iteration 1800 / 2000: loss 2.302686
# iteration 1900 / 2000: loss 2.302426
# learning rate 0.00217264582825
# regularization strength: 0.00681714233509
# Hidden layer is 91
# accuarcy  0.079
# iteration 0 / 2000: loss 2.302596
# iteration 100 / 2000: loss 2.301886
# iteration 200 / 2000: loss 2.302750
# iteration 300 / 2000: loss 2.302420
# iteration 400 / 2000: loss 2.300932
# iteration 500 / 2000: loss 2.285351
# iteration 600 / 2000: loss 2.225690
# iteration 700 / 2000: loss 2.169927
# iteration 800 / 2000: loss 2.053362
# iteration 900 / 2000: loss 2.085805
# iteration 1000 / 2000: loss 2.015300
# iteration 1100 / 2000: loss 1.995036
# iteration 1200 / 2000: loss 2.087358
# iteration 1300 / 2000: loss 1.906599
# iteration 1400 / 2000: loss 1.974307
# iteration 1500 / 2000: loss 1.939121
# iteration 1600 / 2000: loss 1.925851
# iteration 1700 / 2000: loss 1.995388
# iteration 1800 / 2000: loss 1.897622
# iteration 1900 / 2000: loss 1.886140
# learning rate 0.0199638326202
# regularization strength: 0.0693118558426
# Hidden layer is 188
# accuarcy  0.404
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.302070
# iteration 200 / 2000: loss 2.303059
# iteration 300 / 2000: loss 2.302269
# iteration 400 / 2000: loss 2.302761
# iteration 500 / 2000: loss 2.302292
# iteration 600 / 2000: loss 2.302644
# iteration 700 / 2000: loss 2.302039
# iteration 800 / 2000: loss 2.299367
# iteration 900 / 2000: loss 2.287902
# iteration 1000 / 2000: loss 2.256483
# iteration 1100 / 2000: loss 2.216576
# iteration 1200 / 2000: loss 2.164924
# iteration 1300 / 2000: loss 2.126589
# iteration 1400 / 2000: loss 2.044147
# iteration 1500 / 2000: loss 1.991763
# iteration 1600 / 2000: loss 1.927874
# iteration 1700 / 2000: loss 1.872450
# iteration 1800 / 2000: loss 1.798981
# iteration 1900 / 2000: loss 1.890296
# learning rate 0.0101761244413
# regularization strength: 0.0051602577515
# Hidden layer is 74
# accuarcy  0.309
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.303078
# iteration 200 / 2000: loss 2.302640
# iteration 300 / 2000: loss 2.302164
# iteration 400 / 2000: loss 2.302495
# iteration 500 / 2000: loss 2.301620
# iteration 600 / 2000: loss 2.302142
# iteration 700 / 2000: loss 2.299888
# iteration 800 / 2000: loss 2.294903
# iteration 900 / 2000: loss 2.274955
# iteration 1000 / 2000: loss 2.245556
# iteration 1100 / 2000: loss 2.111682
# iteration 1200 / 2000: loss 2.121905
# iteration 1300 / 2000: loss 1.980351
# iteration 1400 / 2000: loss 1.981104
# iteration 1500 / 2000: loss 1.829577
# iteration 1600 / 2000: loss 1.897390
# iteration 1700 / 2000: loss 1.795759
# iteration 1800 / 2000: loss 1.822012
# iteration 1900 / 2000: loss 1.702152
# learning rate 0.0107545634372
# regularization strength: 0.0016544398064
# Hidden layer is 152
# accuarcy  0.376
# iteration 0 / 2000: loss 2.302625
# iteration 100 / 2000: loss 2.302491
# iteration 200 / 2000: loss 2.302560
# iteration 300 / 2000: loss 2.302447
# iteration 400 / 2000: loss 2.302846
# iteration 500 / 2000: loss 2.301545
# iteration 600 / 2000: loss 2.302333
# iteration 700 / 2000: loss 2.303344
# iteration 800 / 2000: loss 2.302977
# iteration 900 / 2000: loss 2.302091
# iteration 1000 / 2000: loss 2.302363
# iteration 1100 / 2000: loss 2.302282
# iteration 1200 / 2000: loss 2.301984
# iteration 1300 / 2000: loss 2.302245
# iteration 1400 / 2000: loss 2.302269
# iteration 1500 / 2000: loss 2.302183
# iteration 1600 / 2000: loss 2.302623
# iteration 1700 / 2000: loss 2.302045
# iteration 1800 / 2000: loss 2.301902
# iteration 1900 / 2000: loss 2.301821
# learning rate 0.00773230506462
# regularization strength: 0.19213837373
# Hidden layer is 248
# accuarcy  0.087
# iteration 0 / 2000: loss 2.302665
# iteration 100 / 2000: loss 2.302283
# iteration 200 / 2000: loss 2.304456
# iteration 300 / 2000: loss 2.302787
# iteration 400 / 2000: loss 2.302466
# iteration 500 / 2000: loss 2.301635
# iteration 600 / 2000: loss 2.303596
# iteration 700 / 2000: loss 2.302357
# iteration 800 / 2000: loss 2.303217
# iteration 900 / 2000: loss 2.301691
# iteration 1000 / 2000: loss 2.301991
# iteration 1100 / 2000: loss 2.301348
# iteration 1200 / 2000: loss 2.303248
# iteration 1300 / 2000: loss 2.303310
# iteration 1400 / 2000: loss 2.303214
# iteration 1500 / 2000: loss 2.303063
# iteration 1600 / 2000: loss 2.303099
# iteration 1700 / 2000: loss 2.301969
# iteration 1800 / 2000: loss 2.301864
# iteration 1900 / 2000: loss 2.302353
# learning rate 0.0419991727475
# regularization strength: 0.643074939015
# Hidden layer is 149
# accuarcy  0.113
# iteration 0 / 2000: loss 2.302585
# iteration 100 / 2000: loss 2.300383
# iteration 200 / 2000: loss 2.286968
# iteration 300 / 2000: loss 1.970164
# iteration 400 / 2000: loss 1.835600
# iteration 500 / 2000: loss 1.654478
# iteration 600 / 2000: loss 1.605624
# iteration 700 / 2000: loss 1.416918
# iteration 800 / 2000: loss 1.598371
# iteration 900 / 2000: loss 1.460835
# iteration 1000 / 2000: loss 1.344950
# iteration 1100 / 2000: loss 1.397248
# iteration 1200 / 2000: loss 1.409002
# iteration 1300 / 2000: loss 1.369075
# iteration 1400 / 2000: loss 1.334543
# iteration 1500 / 2000: loss 1.463887
# iteration 1600 / 2000: loss 1.354894
# iteration 1700 / 2000: loss 1.222260
# iteration 1800 / 2000: loss 1.441648
# iteration 1900 / 2000: loss 1.328445
# learning rate 0.0456444719306
# regularization strength: 0.00586350845339
# Hidden layer is 69
# accuarcy  0.529
# lr 0.001069 rs 0.089976 hidden_size 128  val accuracy: 0.078000
# lr 0.001075 rs 0.073330 hidden_size 114  val accuracy: 0.102000
# lr 0.001098 rs 0.002866 hidden_size 147  val accuracy: 0.087000
# lr 0.001155 rs 0.163793 hidden_size 305  val accuracy: 0.079000
# lr 0.001192 rs 0.006876 hidden_size 80  val accuracy: 0.087000
# lr 0.001222 rs 0.002857 hidden_size 216  val accuracy: 0.079000
# lr 0.001303 rs 0.040710 hidden_size 184  val accuracy: 0.078000
# lr 0.001305 rs 0.652765 hidden_size 84  val accuracy: 0.087000
# lr 0.001391 rs 0.065328 hidden_size 124  val accuracy: 0.079000
# lr 0.001457 rs 0.250001 hidden_size 165  val accuracy: 0.078000
# lr 0.001538 rs 0.010252 hidden_size 136  val accuracy: 0.087000
# lr 0.001539 rs 0.030219 hidden_size 225  val accuracy: 0.098000
# lr 0.001566 rs 0.179271 hidden_size 184  val accuracy: 0.112000
# lr 0.001592 rs 0.038025 hidden_size 68  val accuracy: 0.079000
# lr 0.001688 rs 0.001186 hidden_size 129  val accuracy: 0.079000
# lr 0.001739 rs 0.014381 hidden_size 129  val accuracy: 0.079000
# lr 0.001768 rs 0.001434 hidden_size 55  val accuracy: 0.079000
# lr 0.001775 rs 0.002245 hidden_size 313  val accuracy: 0.078000
# lr 0.001811 rs 0.001412 hidden_size 163  val accuracy: 0.079000
# lr 0.001915 rs 0.204905 hidden_size 173  val accuracy: 0.079000
# lr 0.002077 rs 0.021417 hidden_size 225  val accuracy: 0.078000
# lr 0.002158 rs 0.167660 hidden_size 263  val accuracy: 0.079000
# lr 0.002173 rs 0.006817 hidden_size 91  val accuracy: 0.079000
# lr 0.002248 rs 0.151281 hidden_size 123  val accuracy: 0.078000
# lr 0.002877 rs 0.007408 hidden_size 169  val accuracy: 0.079000
# lr 0.003099 rs 0.078625 hidden_size 106  val accuracy: 0.079000
# lr 0.003191 rs 0.201105 hidden_size 151  val accuracy: 0.102000
# lr 0.003290 rs 0.737755 hidden_size 100  val accuracy: 0.107000
# lr 0.003373 rs 0.055449 hidden_size 52  val accuracy: 0.087000
# lr 0.003919 rs 0.003673 hidden_size 60  val accuracy: 0.078000
# lr 0.004039 rs 0.001305 hidden_size 66  val accuracy: 0.113000
# lr 0.004659 rs 0.001405 hidden_size 179  val accuracy: 0.147000
# lr 0.004731 rs 0.036893 hidden_size 95  val accuracy: 0.195000
# lr 0.004838 rs 0.048473 hidden_size 275  val accuracy: 0.157000
# lr 0.005279 rs 0.054422 hidden_size 144  val accuracy: 0.163000
# lr 0.005402 rs 0.249161 hidden_size 127  val accuracy: 0.079000
# lr 0.005477 rs 0.243510 hidden_size 137  val accuracy: 0.084000
# lr 0.005745 rs 0.006781 hidden_size 296  val accuracy: 0.231000
# lr 0.005969 rs 0.013216 hidden_size 171  val accuracy: 0.208000
# lr 0.006089 rs 0.503798 hidden_size 144  val accuracy: 0.078000
# lr 0.006198 rs 0.079614 hidden_size 104  val accuracy: 0.144000
# lr 0.006332 rs 0.016054 hidden_size 112  val accuracy: 0.211000
# lr 0.006422 rs 0.397970 hidden_size 207  val accuracy: 0.079000
# lr 0.006592 rs 0.364043 hidden_size 163  val accuracy: 0.105000
# lr 0.006695 rs 0.721469 hidden_size 136  val accuracy: 0.098000
# lr 0.007168 rs 0.015944 hidden_size 117  val accuracy: 0.249000
# lr 0.007702 rs 0.177680 hidden_size 211  val accuracy: 0.129000
# lr 0.007732 rs 0.192138 hidden_size 248  val accuracy: 0.087000
# lr 0.008053 rs 0.042629 hidden_size 54  val accuracy: 0.231000
# lr 0.008222 rs 0.221302 hidden_size 118  val accuracy: 0.090000
# lr 0.009172 rs 0.043345 hidden_size 189  val accuracy: 0.288000
# lr 0.009831 rs 0.401046 hidden_size 57  val accuracy: 0.078000
# lr 0.010176 rs 0.005160 hidden_size 74  val accuracy: 0.309000
# lr 0.010755 rs 0.001654 hidden_size 152  val accuracy: 0.376000
# lr 0.011425 rs 0.013384 hidden_size 77  val accuracy: 0.347000
# lr 0.011624 rs 0.369669 hidden_size 145  val accuracy: 0.087000
# lr 0.012977 rs 0.005878 hidden_size 303  val accuracy: 0.424000
# lr 0.013641 rs 0.001586 hidden_size 75  val accuracy: 0.408000
# lr 0.014545 rs 0.015661 hidden_size 96  val accuracy: 0.402000
# lr 0.016101 rs 0.006742 hidden_size 241  val accuracy: 0.451000
# lr 0.016284 rs 0.011299 hidden_size 99  val accuracy: 0.444000
# lr 0.016301 rs 0.012694 hidden_size 171  val accuracy: 0.444000
# lr 0.017060 rs 0.076204 hidden_size 195  val accuracy: 0.368000
# lr 0.018406 rs 0.576783 hidden_size 262  val accuracy: 0.102000
# lr 0.018416 rs 0.035288 hidden_size 159  val accuracy: 0.437000
# lr 0.018829 rs 0.157358 hidden_size 218  val accuracy: 0.292000
# lr 0.018867 rs 0.001770 hidden_size 246  val accuracy: 0.481000
# lr 0.019921 rs 0.021212 hidden_size 138  val accuracy: 0.459000
# lr 0.019964 rs 0.069312 hidden_size 188  val accuracy: 0.404000
# lr 0.020743 rs 0.004403 hidden_size 188  val accuracy: 0.488000
# lr 0.021671 rs 0.952450 hidden_size 112  val accuracy: 0.078000
# lr 0.022320 rs 0.029587 hidden_size 148  val accuracy: 0.460000
# lr 0.024673 rs 0.013227 hidden_size 305  val accuracy: 0.489000
# lr 0.029725 rs 0.004943 hidden_size 60  val accuracy: 0.515000
# lr 0.034900 rs 0.214744 hidden_size 224  val accuracy: 0.268000
# lr 0.035039 rs 0.001689 hidden_size 110  val accuracy: 0.520000
# lr 0.036491 rs 0.019555 hidden_size 102  val accuracy: 0.503000
# lr 0.037006 rs 0.006328 hidden_size 155  val accuracy: 0.509000
# lr 0.039704 rs 0.009078 hidden_size 72  val accuracy: 0.517000
# lr 0.040342 rs 0.750140 hidden_size 58  val accuracy: 0.098000
# lr 0.041108 rs 0.006280 hidden_size 50  val accuracy: 0.506000
# lr 0.041999 rs 0.643075 hidden_size 149  val accuracy: 0.113000
# lr 0.043505 rs 0.005575 hidden_size 312  val accuracy: 0.521000
# lr 0.045644 rs 0.005864 hidden_size 69  val accuracy: 0.529000
# lr 0.048111 rs 0.125237 hidden_size 209  val accuracy: 0.392000
# lr 0.051554 rs 0.002054 hidden_size 191  val accuracy: 0.530000
# lr 0.056415 rs 0.007960 hidden_size 120  val accuracy: 0.521000
# lr 0.056602 rs 0.004597 hidden_size 50  val accuracy: 0.531000
# lr 0.059155 rs 0.001334 hidden_size 141  val accuracy: 0.536000
# lr 0.059172 rs 0.155227 hidden_size 56  val accuracy: 0.363000
# lr 0.061379 rs 0.011631 hidden_size 111  val accuracy: 0.522000
# lr 0.069896 rs 0.004883 hidden_size 55  val accuracy: 0.535000
# lr 0.073113 rs 0.004629 hidden_size 212  val accuracy: 0.547000
# lr 0.076378 rs 0.053408 hidden_size 56  val accuracy: 0.493000
# lr 0.077967 rs 0.032452 hidden_size 64  val accuracy: 0.504000
# lr 0.079852 rs 0.008677 hidden_size 151  val accuracy: 0.532000
# lr 0.080470 rs 0.013472 hidden_size 298  val accuracy: 0.525000
# lr 0.081970 rs 0.909950 hidden_size 58  val accuracy: 0.078000
# lr 0.087684 rs 0.408387 hidden_size 112  val accuracy: 0.207000
# lr 0.093783 rs 0.003960 hidden_size 172  val accuracy: 0.569000
# best validation accuracy achieved during cross-validation: 0.569000

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.548

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
